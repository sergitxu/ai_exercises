# %% [markdown]
# <a href="https://colab.research.google.com/github/sergitxu/ai_exercises/blob/master/Exercise_1_House_Prices_Question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# In this exercise you'll try to build a neural network that predicts the price of a house according to a simple formula.
#
# So, imagine if house pricing was as easy as a house costs 50k + 50k per bedroom, so that a 1 bedroom house costs 100k, a 2 bedroom house costs 150k etc.
#
# How would you create a neural network that learns this relationship so that it would predict a 7 bedroom house as costing close to 400k etc.
#
# Hint: Your network might work better if you scale the house price down. You don't have to give the answer 400...it might be better to create something that predicts the number 4, and then your answer is in the 'hundreds of thousands' etc.

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras
model = keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])
model.compile(optimizer='sgd', loss='mean_squared_error')
xs = np.array([0.0,1.0,2.0,3.0,4.0], dtype=float)
ys = np.array([0.5,1.0,1.5,2.0,2.5], dtype=float)
model.fit(xs, ys, epochs=600)
print(model.predict([7.0]))
# Out:
# Epoch 1/600
# 5/5 [==============================] - 0s 21ms/sample - loss: 2.3177
# Epoch 2/600
# 5/5 [==============================] - 0s 561us/sample - loss: 1.7758
# Epoch 3/600
# 5/5 [==============================] - 0s 417us/sample - loss: 1.3690
# Epoch 4/600
# 5/5 [==============================] - 0s 399us/sample - loss: 1.0635
# Epoch 5/600
# 5/5 [==============================] - 0s 460us/sample - loss: 0.8340
# Epoch 6/600
# 5/5 [==============================] - 0s 431us/sample - loss: 0.6614
# Epoch 7/600
# 5/5 [==============================] - 0s 462us/sample - loss: 0.5316
# Epoch 8/600
# 5/5 [==============================] - 0s 448us/sample - loss: 0.4338
# Epoch 9/600
# 5/5 [==============================] - 0s 683us/sample - loss: 0.3600
# Epoch 10/600
# 5/5 [==============================] - 0s 599us/sample - loss: 0.3043
# Epoch 11/600
# 5/5 [==============================] - 0s 351us/sample - loss: 0.2621
# Epoch 12/600
# ...
